# %% [markdown]
# ### Q1. Install the Package

# %%
# !wandb --version
# Out:
# wandb, version 0.15.3

# %% [markdown]
# ### Q2. Download and preprocess the data

# %%
# !python preprocess_data.py \
  --wandb_project mlopszoomcamp_week_2 \
  --wandb_entity vdmshestopalov \
  --raw_data_path /Users/vchulski/Developer/mlzoomcamp/week_2/data \
  --dest_path /Users/vchulski/Developer/mlzoomcamp/week_2/output_wandb
# Out:
# wandb: Currently logged in as: vdmshestopalov. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /Users/vchulski/Developer/mlzoomcamp/week_2/wandb/wandb/run-20230606_181412-15s52a9u
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run stellar-elevator-1
# wandb: ⭐️ View project at https://wandb.ai/vdmshestopalov/mlopszoomcamp_week_2
# wandb: 🚀 View run at https://wandb.ai/vdmshestopalov/mlopszoomcamp_week_2/runs/15s52a9u
# wandb: Adding directory to artifact (/Users/vchulski/Developer/mlzoomcamp/week_2/output_wandb)... Done. 0.1s
# wandb: Waiting for W&B process to finish... (success).
# wandb: 🚀 View run stellar-elevator-1 at: https://wandb.ai/vdmshestopalov/mlopszoomcamp_week_2/runs/15s52a9u
# wandb: Synced 5 W&B file(s), 0 media file(s), 6 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_181412-15s52a9u/logs

# %%
# !ls -lh /Users/vchulski/Developer/mlzoomcamp/week_2/output_wandb
# Out:
# total 14208
# -rw-r--r--  1 vchulski  staff   150K Jun  6 18:14 dv.pkl
# -rw-r--r--  1 vchulski  staff   2.5M Jun  6 18:14 test.pkl
# -rw-r--r--  1 vchulski  staff   2.0M Jun  6 18:14 train.pkl
# -rw-r--r--  1 vchulski  staff   2.2M Jun  6 18:14 val.pkl

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Q3. Train a model with Weights & Biases logging

# %%
# !python train.py \
  --wandb_project mlopszoomcamp_week_2 \
  --wandb_entity vdmshestopalov \
  --data_artifact "vdmshestopalov/mlopszoomcamp_week_2/NYC-Taxi:v0"
# Out:
# wandb: Currently logged in as: vdmshestopalov. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /Users/vchulski/Developer/mlzoomcamp/week_2/wandb/wandb/run-20230606_182408-f9agbsep
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run kind-terrain-2
# wandb: ⭐️ View project at https://wandb.ai/vdmshestopalov/mlopszoomcamp_week_2
# wandb: 🚀 View run at https://wandb.ai/vdmshestopalov/mlopszoomcamp_week_2/runs/f9agbsep
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.45398
# wandb:
# wandb: 🚀 View run kind-terrain-2 at: https://wandb.ai/vdmshestopalov/mlopszoomcamp_week_2/runs/f9agbsep
# wandb: Synced 5 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230606_182408-f9agbsep/logs

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Q4. Tune model hyperparameters

# %%
# !python sweep.py \
  --wandb_project mlopszoomcamp_week_2 \
  --wandb_entity vdmshestopalov \
  --data_artifact "vdmshestopalov/mlopszoomcamp_week_2/NYC-Taxi:v0"
# Out:
# Create sweep with ID: mmucnsug
# Sweep URL: https://wandb.ai/vdmshestopalov/mlopszoomcamp_week_2/sweeps/mmucnsug
# wandb: Agent Starting Run: sam923pt with config:
# wandb: 	max_depth: 20
# wandb: 	min_samples_leaf: 1
# wandb: 	min_samples_split: 2
# wandb: 	n_estimators: 45
# wandb: Currently logged in as: vdmshestopalov. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /Users/vchulski/Developer/mlzoomcamp/week_2/wandb/wandb/run-20230606_182901-sam923pt
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run hardy-sweep-1
# wandb: ⭐️ View project at https://wandb.ai/vdmshestopalov/mlopszoomcamp_week_2
# wandb: 🧹 View sweep at https://wandb.ai/vdmshestopalov/mlopszoomcamp_week_2/sweeps/mmucnsug
# wandb: 🚀 View run at https://wandb.ai/vdmshestopalov/mlopszoomcamp_week_2/runs/sam923pt
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Q5. Link the best model to the model registry

# %% [markdown]
# ![image.png](attachment:image.png)
